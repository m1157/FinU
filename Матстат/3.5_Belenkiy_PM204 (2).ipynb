# %% [markdown]
# ## 3.5.

# %%
import numpy as np
from scipy.stats import f
import matplotlib.pyplot as plt

font = {'family': 'serif', 'serif': 'Times New Roman', 'weight': 'normal','size':15}
plt.rc('font',**font)

# %% [markdown]
# ![351.png](attachment:351.png)

# %% [markdown]
# ![352.png](attachment:352.png)

# %%
f_1 = f.pdf(x,2,10)
f_2 = f.pdf(x,5,10)
f_3 = f.pdf(x,20,10)

# %%
fig,ax =plt.subplots(figsize=(7, 7))
plt.tick_params(labelsize = 20)
plt.tick_params(labelsize = 20)
plt.grid(color='k', alpha=0.75, linestyle=':', linewidth=1)

plt.xlim(0,3)
plt.ylim(0,1)

plt.title('Плотность распределения Фишера', fontweight='normal')
x = np.linspace(0,3,2000)
plt.plot(x,f_1,color='c',lw=2)
plt.plot(x,f_2,color='m',lw=2)
plt.plot(x,f_3,color='y',lw=2)
plt.legend(["n=2, m=10","n=5, m=10","n=20, m=10"],loc = 'upper right')
plt.show()

# %% [markdown]
# ![354.png](attachment:354.png)

# %%
#1
n = 3
m = 16
c = 3.24
X = f(n,m)

print(f'1. P = {X.cdf(c)}')
# Out:
# 1. P = 0.9500484960319404

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X = f.pdf(x,3,16)
fig,ax =plt.subplots(figsize=(7, 7))
plt.tick_params(labelsize = 20)
plt.tick_params(labelsize = 20)
plt.grid(color='k', alpha=0.75, linestyle=':', linewidth=1)

plt.xlim(-2-0.1,6+0.1)
plt.ylim(0,1)

plt.title('PDF f(3,16)', fontweight='normal')
x = np.linspace(-2,6,2000)
plt.plot(x,X,color='c',lw=2)
ax.vlines(c, 0, 1, color = 'm', linestyle='--')
plt.legend([f'f({n},{m})',f'{c}'],loc = 'upper right')
plt.show()

# %%
#2
n = 35
m = 100
c = 1.3
X = f(n,m)

print(f'2. P = {1 - X.cdf(c)}')
# Out:
# 2. P = 0.1575835371726052

# %%
X = f.pdf(x,35,100)
fig,ax =plt.subplots(figsize=(7, 7))
plt.tick_params(labelsize = 20)
plt.tick_params(labelsize = 20)
plt.grid(color='k', alpha=0.75, linestyle=':', linewidth=1)

plt.xlim(-2-0.1,6+0.1)
plt.ylim(0,2)

plt.title('PDF f(3,16)', fontweight='normal')
x = np.linspace(-2,6,2000)
plt.plot(x,X,color='c',lw=2)
ax.vlines(c, 0, 2, color = 'm', linestyle='--')
plt.legend([f'f({n},{m})',f'{c}'],loc = 'upper right')
plt.show()

# %% [markdown]
# ![355.png](attachment:355.png)

# %%
#1
n = 3
m = 7
c = 0.05
X = f(n,m)

print(f'1. {X.isf(c)}')
# Out:
# 1. 4.346831399907815

# %%
#2
n = 7
m = 3
c = 0.05
X = f(n,m)

print(f'2. {X.isf(c)}')
# Out:
# 2. 8.886742955634274

# %%
#3
n = 5
m = 20
c = 0.025
X = f(n,m)

print(f'3. {X.isf(c)}')
# Out:
# 3. 3.289055845680407

# %%
#1
n = 300
m = 800
c = 0.05
X = f(n,m)

print(f'4. {X.isf(c)}')
# Out:
# 4. 1.166967969509093
