# %% [markdown]
# ![74.png](attachment:74.png)

# %% [markdown]
# ![721.png](attachment:721.png)

# %%
import numpy as np
import math
xi = [2.5, 7.5, 12.5, 17.5, 22.5, 27.5]
ni = [133, 45, 15, 4, 2, 1]
n = 200

# %% [markdown]
# #### 1-ый и 2-ой моменты

# %% [markdown]
# $${\displaystyle E(x) = {\frac {1}{\lambda }}}$$
#
# $${\displaystyle Var(x) = \lambda ^{-2}}$$

# %%
E = 0
for i in range(len(xi)):
    E += xi[i]*ni[i]
E = E/n
E
# Out:
# 5.0

# %%
l = 1/E
l
# Out:
# 0.2

# %% [markdown]
# #### Функция распределения

# %% [markdown]
# $${\displaystyle F(x) = 1-e^{-\lambda x}}$$

# %% [markdown]
# $$P(x=5) = e^{-\lambda t}$$

# %%
# x = -1/l*math.ln(0.9)
x = 0.562
x
# Out:
# 0.562
