# %% [markdown]
# ![75.png](attachment:75.png)

# %%
mean = 0.9
p_i = 0.75
interval = [0,1]

# %% [markdown]
# $${\displaystyle \int _{-\infty }^{x}f(t)\,{\mbox{d}}t=F(x)}$$

# %% [markdown]
# $${\displaystyle \mathbb {E} [X]=\int \limits _{-\infty }^{\infty }\!xf_{X}(x)\,dx}$$

# %% [markdown]
# ![751.png](attachment:751.png)

# %%
b = 9

# %%
P = p_i**b
P
# Out:
# 0.07508468627929688
