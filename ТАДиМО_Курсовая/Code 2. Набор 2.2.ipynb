# %% [markdown]
# # <span style="font-family:Times New Roman">Code 2. Набор 2.2</span>

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import pandas as pd
import numpy as np
import pickle
import time

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score, precision_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, LSTM, Dropout

from get_features import get_song_features_set_1

# %% [markdown]
# Импортируем стиль визуализации из файла `custom_mplstyle.txt`

# %%
plt.style.use('ExtraData\\custom_mplstyle.txt')

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"')

# %% [markdown]
# Импортируем необходимые списки

# %%
with open('genre_names.txt', 'r') as f:
    genre_names = f.read().split(';')

# %%
with open('genre_names_rus.txt', 'r') as f:
    genre_names_rus = f.read().split(';')

# %%
with open('genre_codes.pkl', 'rb') as f:
    genre_codes = pickle.load(f)

# %% [markdown]
# ## <span style="font-family:Times New Roman">Описание набора данных:</span>
# #### 22 параметра, 5 делений, 5000 аудиофайлов по 6 секунд, shape = (5000, 22)</span>
#
# |   №  |       Параметр      ||   №  |    Параметр   |
# |------|---------------------||------|---------------|
# |**1** |centroid $mean$      ||**12**|mfcc$_1$ $mean$|
# |**2** |centroid $std$       ||**13**|mfcc$_1$ $std$ |
# |**3** |rolloff $mean$       ||**14**|mfcc$_2$ $mean$|
# |**4** |rolloff $std$        ||**15**|mfcc$_2$ $std$ |
# |**5** |bandwidth $mean$     ||**16**|mfcc$_3$ $mean$|
# |**6** |bandwidth $std$      ||**17**|mfcc$_3$ $std$ |
# |**7** |flux $mean$          ||**18**|mfcc$_4$ $mean$|
# |**8** |flux $std$           ||**19**|mfcc$_4$ $std$ |
# |**9** |zero crossings $mean$||**20**|mfcc$_5$ $mean$|
# |**10**|zero crossings $std$ ||**21**|mfcc$_5$ $std$ |
# |**11**|low energy           ||**22**|tempo          |

# %% [markdown]
# ## <span style="font-family:Times New Roman">Используемые функции:</span>
#
# **1\.** `confusion_martix_plot` – график матрицы ошибок
#
# Визуализируем матрицу ошибок, которая показывает производительность модели

# %%
def confusion_martix_plot(test, pred, acc, model_type, save=True):
    cm = confusion_matrix(test, pred)

    fig, axes = plt.subplots(1, 1, figsize=(10,7))
    fig.patch.set_facecolor('#371d49')
    
    sns.heatmap(cm,
                linewidths=.5,
                linecolor="black",
                cmap=plt.cm.RdPu_r,
                annot=True, 
                fmt='g',
                annot_kws={'fontsize':18},
                xticklabels=genre_names,
                yticklabels=genre_names)
    
    plt.title(f'Accuracy = {acc:.2f}', fontsize=22, y=1.05)
    plt.xlabel('Predicted', fontsize=18)
    plt.ylabel('Real', fontsize=18)
    
    fn = file_name.split('.')[0].replace(' ', '_').lower()
    lt = '_'.join(str(x) for x in list(time.localtime())[1:-3])
    if save:
        plt.savefig(f'Images/cm_{fn}_{model_type}_{lt}.png', facecolor='#371d49', bbox_inches = 'tight', dpi = 300)
    plt.show()

# %% [markdown]
# **2\.** `plot_performance` – график обучения модели
#
# Визуализируем изменение `accuracy` и `loss` значений в процессе обучения модели

# %%
def performance_plot(hist, save=False):

    acc = hist.history['acc']
    val_acc = hist.history['val_acc']
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']
    epochs = range(len(acc))
    
    fig, axes = plt.subplots(ncols=2, figsize=(12, 4))
    
    line_1 = axes[0].plot(epochs, acc, '#18c0c4', label='Training accuracy')
    line_2 = axes[0].plot(epochs, val_acc, '#fefeff', label='Validation accuracy')
    axes[0].set_title('Training and validation accuracy')

    line_3 = axes[1].plot(epochs, loss, '#A267F5', label='Training Loss')
    line_4 = axes[1].plot(epochs, val_loss, '#f62196', label='Validation Loss')
    axes[1].set_title('Training and validation loss')

    lines = line_1 + line_2 + line_3 + line_4
    labs = [l.get_label() for l in lines]
    plt.legend(lines, labs, loc='center', bbox_to_anchor=(1.2, 0.5))
    lt = '_'.join(str(x) for x in list(time.localtime())[1:-3])
    if save:
        plt.savefig(f'Images/performance_{lt}.png', bbox_inches = 'tight', dpi = 300)
    plt.show()

# %% [markdown]
# **3\.** `prepare_datasets` – предобработка данных
#
# С помощью `sklearn.model_selection.train_test_split` разделяем данные в два этапа: на `train` – `validation` выборки и на `train` – `test` выборки. Также, приводим данные в трёхмерную форму:

# %%
def prepare_datasets(X, Y, split_size):
    scaler = StandardScaler()
    scaler.fit(X)
    X = scaler.transform(X)
    
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=split_size, random_state=5)
    X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=split_size, random_state=5)
    
    X_train = X_train[..., np.newaxis]
    X_val = X_val[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    
    return X_train, X_val, X_test, Y_train, Y_val, Y_test

# %% [markdown]
# ## <span style="font-family:Times New Roman">Импорт данных</span>
# Загружаем данные из файла `features_set_2_2.csv`

# %%
features = pd.read_csv('Sets/features_set_2_2.csv', index_col=[0])

# %%
features.shape
# Out:
# (5000, 23)

# %% [markdown]
# Разделяем датасет на `X` и `Y`:

# %%
X = features.drop(columns=['genre'])
Y = features['genre']

# %% [markdown]
# С помощью функции `prepare_datasets` разделяем данные на обучающую, валидационную и тестовую выборки:

# %%
X_train, X_val, X_test, Y_train, Y_val, Y_test = prepare_datasets(X, Y, 0.2)

input_shape = X_train.shape[1:]
input_shape
# Out:
# (22, 1)

# %% [markdown]
# ## <span style="font-family:Times New Roman">1\. CNN (Convolutional Neural Network)</span>
# Функция `CNN_model` содержит архитектуру CNN-модели:

# %%
def CNN_model(input_shape):

    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(filters=128, kernel_size=2, activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPooling1D(pool_size=1),

        tf.keras.layers.Conv1D(filters=128, kernel_size=2, activation='relu'),
        tf.keras.layers.MaxPooling1D(pool_size=1),        
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Conv1D(filters=256, kernel_size=16, activation='relu'),
        tf.keras.layers.MaxPooling1D(pool_size=1),        
        tf.keras.layers.Dropout(0.2),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax', 
                              kernel_regularizer=tf.keras.regularizers.L1(l=0.15)
                             )
    ])

    return model

# %% [markdown]
# ### <span style="font-family:Times New Roman">Компилируем и обучаем модель</span>
# * Оптимизатор: **RMSprop**, learning rate = $5e-3$
# * Функция потерь (Loss function): **SparseCategoricalCrossentropy**  – для двух и более классов целовчисленных меток
# * Количество эпох: **40**
# * Размер батча: **32**
# * Для каждой эпохи рассчитывается `loss`, `accuracy` для обучающей и валидационных выборок

# %%
model = CNN_model(input_shape)

model.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.005),
              loss='sparse_categorical_crossentropy',
              metrics = ['acc'])

history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val),
                    epochs=40, batch_size=32)

performance_plot(history)
# Out:
# Epoch 1/40
# 100/100 [==============================] - 2s 11ms/step - loss: 4.2259 - acc: 0.3756 - val_loss: 1.9408 - val_acc: 0.4830
# Epoch 2/40
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7323 - acc: 0.5500 - val_loss: 1.5261 - val_acc: 0.5950
# Epoch 3/40
# 100/100 [==============================] - 1s 10ms/step - loss: 1.5189 - acc: 0.6122 - val_loss: 1.5803 - val_acc: 0.5970
# Epoch 4/40
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4143 - acc: 0.6531 - val_loss: 1.4408 - val_acc: 0.6490
# Epoch 5/40
# 100/100 [==============================] - 1s 9ms/step - loss: 1.3034 - acc: 0.6953 - val_loss: 1.4175 - val_acc: 0.6510
# Epoch 6/40
# 100/100 [==============================] - 1s 9ms/step - loss: 1.2159 - acc: 0.7247 - val_loss: 1.3191 - val_acc: 0.6940
# Epoch 7/40
# 100/100 [==============================] - 1s 9ms/step - loss: 1.1761 - acc: 0.7337 - val_loss: 1.2506 - val_acc: 0.7210
# Epoch 8/40
# 100/100 [==============================] - 1s 9ms/step - loss: 1.1055 - acc: 0.7600 - val_loss: 1.3464 - val_acc: 0.6890
# Epoch 9/40
# 100/100 [==============================] - 1s 9ms/step - loss: 1.0557 - acc: 0.7703 - val_loss: 1.3627 - val_acc: 0.7010
# Epoch 10/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.9946 - acc: 0.7981 - val_loss: 1.2534 - val_acc: 0.7310
# Epoch 11/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.9695 - acc: 0.7978 - val_loss: 1.3119 - val_acc: 0.7150
# Epoch 12/40
# 100/100 [==============================] - 1s 10ms/step - loss: 0.9208 - acc: 0.8213 - val_loss: 1.1903 - val_acc: 0.7440
# Epoch 13/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.8895 - acc: 0.8291 - val_loss: 1.2445 - val_acc: 0.7350
# Epoch 14/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.8535 - acc: 0.8441 - val_loss: 1.3111 - val_acc: 0.7030
# Epoch 15/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.8341 - acc: 0.8456 - val_loss: 1.2124 - val_acc: 0.7440
# Epoch 16/40
# 100/100 [==============================] - 1s 10ms/step - loss: 0.8209 - acc: 0.8519 - val_loss: 1.1776 - val_acc: 0.7570
# Epoch 17/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.7837 - acc: 0.8625 - val_loss: 1.2062 - val_acc: 0.7610
# Epoch 18/40
# 100/100 [==============================] - 1s 10ms/step - loss: 0.7698 - acc: 0.8662 - val_loss: 1.2868 - val_acc: 0.7480
# Epoch 19/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.7581 - acc: 0.8703 - val_loss: 1.2671 - val_acc: 0.7680
# Epoch 20/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.7377 - acc: 0.8778 - val_loss: 1.2410 - val_acc: 0.7450
# Epoch 21/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.7458 - acc: 0.8725 - val_loss: 1.2290 - val_acc: 0.7590
# Epoch 22/40
# 100/100 [==============================] - 1s 10ms/step - loss: 0.6918 - acc: 0.8969 - val_loss: 1.2348 - val_acc: 0.7670
# Epoch 23/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6974 - acc: 0.8834 - val_loss: 1.2814 - val_acc: 0.7460
# Epoch 24/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6849 - acc: 0.8913 - val_loss: 1.2634 - val_acc: 0.7590
# Epoch 25/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6668 - acc: 0.8991 - val_loss: 1.2148 - val_acc: 0.7660
# Epoch 26/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6496 - acc: 0.9019 - val_loss: 1.2551 - val_acc: 0.7620
# Epoch 27/40
# 100/100 [==============================] - 1s 10ms/step - loss: 0.6513 - acc: 0.9047 - val_loss: 1.2909 - val_acc: 0.7680
# Epoch 28/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6395 - acc: 0.9044 - val_loss: 1.2038 - val_acc: 0.7620
# Epoch 29/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6349 - acc: 0.9069 - val_loss: 1.3005 - val_acc: 0.7490
# Epoch 30/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5976 - acc: 0.9109 - val_loss: 1.2750 - val_acc: 0.7680
# Epoch 31/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6000 - acc: 0.9181 - val_loss: 1.2544 - val_acc: 0.7740
# Epoch 32/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6068 - acc: 0.9106 - val_loss: 1.2657 - val_acc: 0.7680
# Epoch 33/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6146 - acc: 0.9144 - val_loss: 1.2737 - val_acc: 0.7760
# Epoch 34/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5971 - acc: 0.9169 - val_loss: 1.3416 - val_acc: 0.7720
# Epoch 35/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5984 - acc: 0.9187 - val_loss: 1.3156 - val_acc: 0.7750
# Epoch 36/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6064 - acc: 0.9137 - val_loss: 1.3539 - val_acc: 0.7600
# Epoch 37/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5893 - acc: 0.9194 - val_loss: 1.2944 - val_acc: 0.7700
# Epoch 38/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5872 - acc: 0.9206 - val_loss: 1.1938 - val_acc: 0.7870
# Epoch 39/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5794 - acc: 0.9169 - val_loss: 1.3855 - val_acc: 0.7660
# Epoch 40/40
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5682 - acc: 0.9262 - val_loss: 1.2335 - val_acc: 0.7720

# %%
prediction = model.predict(X_test, verbose=0)
Y_pred = np.argmax(prediction, axis=1)

metrics = {' accuracy' : accuracy_score(Y_test, Y_pred), 
           '       f1' : f1_score(Y_test, Y_pred, average='weighted'), 
           '   recall' : recall_score(Y_test, Y_pred, average='weighted'), 
           'precision' : precision_score(Y_test, Y_pred, average='weighted')}

confusion_martix_plot(Y_test, Y_pred, acc=metrics[' accuracy'], model_type='CNN', save=True)

print('Показатели метрик')
for metric, value in metrics.items():
    print(f'{metric}:\t \033[1m{value:.4f}\033[0m')
# Out:
# Показатели метрик
#  accuracy:	 0.8037
#        f1:	 0.8036
#    recall:	 0.8037
# precision:	 0.8100

# %%
model.summary(line_length=90)
# Out:
# Model: "sequential"
# __________________________________________________________________________________________
#  Layer (type)                           Output Shape                        Param #
# ==========================================================================================
#  conv1d (Conv1D)                        (None, 21, 128)                     384
#
#  max_pooling1d (MaxPooling1D)           (None, 21, 128)                     0
#
#  conv1d_1 (Conv1D)                      (None, 20, 128)                     32896
#
#  max_pooling1d_1 (MaxPooling1D)         (None, 20, 128)                     0
#
#  dropout (Dropout)                      (None, 20, 128)                     0
#
#  conv1d_2 (Conv1D)                      (None, 5, 256)                      524544
#
#  max_pooling1d_2 (MaxPooling1D)         (None, 5, 256)                      0
#
#  dropout_1 (Dropout)                    (None, 5, 256)                      0
#
#  flatten (Flatten)                      (None, 1280)                        0
#
#  dense (Dense)                          (None, 64)                          81984
#
#  dense_1 (Dense)                        (None, 10)                          650
#
# ==========================================================================================
# Total params: 640,458
# Trainable params: 640,458
# Non-trainable params: 0
# __________________________________________________________________________________________

# %%
# model.load_weights('cnn_model_set_2_2.h5')

# %% [markdown]
# ## <span style="font-family:Times New Roman">2\. RNN (Recurrent Neural Network)</span>
# Функция `RNN_model` содержит архитектуру RNN-модели:

# %%
def RNN_model(input_shape):

    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(64, return_sequences=True, input_shape=input_shape),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    return model

# %% [markdown]
# ### <span style="font-family:Times New Roman">Компилируем и обучаем модель</span>
# * Оптимизатор: **RMSprop**, learning rate = $1e-2$
# * Функция потерь (Loss function): **SparseCategoricalCrossentropy**  – для двух и более классов целовчисленных меток
# * Количество эпох: **30**
# * Размер батча: **32**
# * Для каждой эпохи рассчитывается `loss`, `accuracy` для обучающей и валидационных выборок

# %%
model = RNN_model(input_shape)

model.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01),
              loss='sparse_categorical_crossentropy',
              metrics = ['acc'])

history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), 
                    epochs=30, batch_size=32)

performance_plot(history)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 2s 9ms/step - loss: 1.4370 - acc: 0.4791 - val_loss: 1.2456 - val_acc: 0.5620
# Epoch 2/30
# 100/100 [==============================] - 1s 6ms/step - loss: 1.1198 - acc: 0.5884 - val_loss: 1.0168 - val_acc: 0.6390
# Epoch 3/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.9985 - acc: 0.6356 - val_loss: 0.9613 - val_acc: 0.6580
# Epoch 4/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.9094 - acc: 0.6831 - val_loss: 0.9884 - val_acc: 0.6750
# Epoch 5/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.8658 - acc: 0.6828 - val_loss: 0.9233 - val_acc: 0.6800
# Epoch 6/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.8144 - acc: 0.7056 - val_loss: 0.9121 - val_acc: 0.6700
# Epoch 7/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7580 - acc: 0.7269 - val_loss: 0.8973 - val_acc: 0.6830
# Epoch 8/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7095 - acc: 0.7484 - val_loss: 0.7931 - val_acc: 0.7190
# Epoch 9/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6684 - acc: 0.7697 - val_loss: 0.7698 - val_acc: 0.7260
# Epoch 10/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6163 - acc: 0.7844 - val_loss: 0.7895 - val_acc: 0.7380
# Epoch 11/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5990 - acc: 0.7906 - val_loss: 0.7265 - val_acc: 0.7560
# Epoch 12/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5231 - acc: 0.8191 - val_loss: 0.8324 - val_acc: 0.7210
# Epoch 13/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4792 - acc: 0.8338 - val_loss: 0.7804 - val_acc: 0.7370
# Epoch 14/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4328 - acc: 0.8466 - val_loss: 0.7472 - val_acc: 0.7800
# Epoch 15/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4023 - acc: 0.8534 - val_loss: 0.8136 - val_acc: 0.7500
# Epoch 16/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3548 - acc: 0.8731 - val_loss: 0.8111 - val_acc: 0.7500
# Epoch 17/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3254 - acc: 0.8766 - val_loss: 0.8659 - val_acc: 0.7660
# Epoch 18/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2934 - acc: 0.8938 - val_loss: 0.8575 - val_acc: 0.7560
# Epoch 19/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2623 - acc: 0.8959 - val_loss: 0.8260 - val_acc: 0.7640
# Epoch 20/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2301 - acc: 0.9222 - val_loss: 0.8530 - val_acc: 0.7700
# Epoch 21/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2047 - acc: 0.9237 - val_loss: 0.9762 - val_acc: 0.7490
# Epoch 22/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1853 - acc: 0.9331 - val_loss: 0.9479 - val_acc: 0.7580
# Epoch 23/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1717 - acc: 0.9400 - val_loss: 1.0494 - val_acc: 0.7670
# Epoch 24/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1571 - acc: 0.9388 - val_loss: 1.0511 - val_acc: 0.7630
# Epoch 25/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1479 - acc: 0.9466 - val_loss: 1.0657 - val_acc: 0.7740
# Epoch 26/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1269 - acc: 0.9547 - val_loss: 1.2006 - val_acc: 0.7480
# Epoch 27/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1211 - acc: 0.9569 - val_loss: 1.1677 - val_acc: 0.7550
# Epoch 28/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1232 - acc: 0.9591 - val_loss: 1.2352 - val_acc: 0.7540
# Epoch 29/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0944 - acc: 0.9694 - val_loss: 1.2761 - val_acc: 0.7460
# Epoch 30/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1037 - acc: 0.9684 - val_loss: 1.2511 - val_acc: 0.7440

# %% [markdown]
# Проверяем модель на тестовой выборке, строим матрицу ошибок и выводим показатели метрик

# %%
prediction = model.predict(X_test, verbose=0)
Y_pred = np.argmax(prediction, axis=1)

metrics = {' accuracy' : accuracy_score(Y_test, Y_pred), 
           '       f1' : f1_score(Y_test, Y_pred, average='weighted'), 
           '   recall' : recall_score(Y_test, Y_pred, average='weighted'), 
           'precision' : precision_score(Y_test, Y_pred, average='weighted')}

confusion_martix_plot(Y_test, Y_pred, acc=metrics[' accuracy'], model_type='RNN', save=False)

print('Показатели метрик')
for metric, value in metrics.items():
    print(f'{metric}:\t \033[1m{value:.4f}\033[0m')
# Out:
# Показатели метрик
#  accuracy:	 0.7850
#        f1:	 0.7850
#    recall:	 0.7850
# precision:	 0.7877

# %% [markdown]
# Выводим сводную информацию о нейронной сети:

# %%
model.summary(line_length=90)
# Out:
# Model: "sequential_43"
# __________________________________________________________________________________________
#  Layer (type)                           Output Shape                        Param #
# ==========================================================================================
#  lstm_21 (LSTM)                         (None, 22, 64)                      16896
#
#  dropout_65 (Dropout)                   (None, 22, 64)                      0
#
#  flatten_43 (Flatten)                   (None, 1408)                        0
#
#  dense_76 (Dense)                       (None, 10)                          14090
#
# ==========================================================================================
# Total params: 30,986
# Trainable params: 30,986
# Non-trainable params: 0
# __________________________________________________________________________________________

# %% [markdown]
# ## <span style="font-family:Times New Roman">3\. Multilayer Perceptron</span>
# Функция `Perceptron_model` содержит архитектуру многослойного перцептрона:

# %%
def Perceptron_model(input_shape):

    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(256, activation='relu', input_shape=input_shape),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    
    return model

# %% [markdown]
# ### <span style="font-family:Times New Roman">Компилируем и обучаем модель</span>
# * Оптимизатор: **adam**
# * Функция потерь (Loss function): **SparseCategoricalCrossentropy**  – для двух и более классов целовчисленных меток
# * Количество эпох: **35**
# * Размер батча: **32**
# * Для каждой эпохи рассчитывается `loss`, `accuracy` для обучающей и валидационных выборок

# %%
model = Perceptron_model(input_shape)

model.compile(optimizer = 'adam',
              loss='sparse_categorical_crossentropy',
              metrics = ['acc'])
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val),
                    epochs=35, batch_size=32)

performance_plot(history, save=True)
# Out:
# Epoch 1/35
# 100/100 [==============================] - 1s 7ms/step - loss: 1.3327 - acc: 0.5225 - val_loss: 1.1147 - val_acc: 0.5980
# Epoch 2/35
# 100/100 [==============================] - 1s 5ms/step - loss: 0.9814 - acc: 0.6522 - val_loss: 0.9760 - val_acc: 0.6570
# Epoch 3/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.8480 - acc: 0.7022 - val_loss: 1.0320 - val_acc: 0.6380
# Epoch 4/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.7624 - acc: 0.7334 - val_loss: 0.9657 - val_acc: 0.6650
# Epoch 5/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.6948 - acc: 0.7513 - val_loss: 0.8572 - val_acc: 0.6980
# Epoch 6/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.6073 - acc: 0.7847 - val_loss: 0.8154 - val_acc: 0.7270
# Epoch 7/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5228 - acc: 0.8172 - val_loss: 0.8981 - val_acc: 0.7040
# Epoch 8/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4749 - acc: 0.8338 - val_loss: 0.8712 - val_acc: 0.7200
# Epoch 9/35
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3982 - acc: 0.8609 - val_loss: 0.7705 - val_acc: 0.7550
# Epoch 10/35
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3195 - acc: 0.8888 - val_loss: 0.8839 - val_acc: 0.7560
# Epoch 11/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2596 - acc: 0.9094 - val_loss: 0.8323 - val_acc: 0.7710
# Epoch 12/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2155 - acc: 0.9219 - val_loss: 0.8902 - val_acc: 0.7880
# Epoch 13/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1664 - acc: 0.9450 - val_loss: 0.8569 - val_acc: 0.7940
# Epoch 14/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1800 - acc: 0.9391 - val_loss: 0.9299 - val_acc: 0.7710
# Epoch 15/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1295 - acc: 0.9572 - val_loss: 0.9338 - val_acc: 0.7850
# Epoch 16/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0992 - acc: 0.9681 - val_loss: 1.0060 - val_acc: 0.7840
# Epoch 17/35
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0911 - acc: 0.9688 - val_loss: 1.2609 - val_acc: 0.7490
# Epoch 18/35
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0792 - acc: 0.9750 - val_loss: 1.0479 - val_acc: 0.8060
# Epoch 19/35
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0384 - acc: 0.9875 - val_loss: 1.0412 - val_acc: 0.8040
# Epoch 20/35
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0227 - acc: 0.9953 - val_loss: 1.1371 - val_acc: 0.8030
# Epoch 21/35
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0337 - acc: 0.9922 - val_loss: 1.3119 - val_acc: 0.7740
# Epoch 22/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0946 - acc: 0.9663 - val_loss: 1.1498 - val_acc: 0.7880
# Epoch 23/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0457 - acc: 0.9844 - val_loss: 1.2935 - val_acc: 0.7870
# Epoch 24/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0511 - acc: 0.9837 - val_loss: 1.3942 - val_acc: 0.7740
# Epoch 25/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0678 - acc: 0.9778 - val_loss: 1.2769 - val_acc: 0.7870
# Epoch 26/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0953 - acc: 0.9709 - val_loss: 1.2313 - val_acc: 0.7850
# Epoch 27/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0264 - acc: 0.9931 - val_loss: 1.2633 - val_acc: 0.7940
# Epoch 28/35
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0146 - acc: 0.9966 - val_loss: 1.2044 - val_acc: 0.8030
# Epoch 29/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0074 - acc: 0.9981 - val_loss: 1.3197 - val_acc: 0.7970
# Epoch 30/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0101 - acc: 0.9978 - val_loss: 1.3073 - val_acc: 0.8080
# Epoch 31/35
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0024 - acc: 0.9997 - val_loss: 1.3123 - val_acc: 0.8060
# Epoch 32/35
# 100/100 [==============================] - 0s 5ms/step - loss: 7.8177e-04 - acc: 1.0000 - val_loss: 1.3393 - val_acc: 0.8010
# Epoch 33/35
# 100/100 [==============================] - 0s 5ms/step - loss: 5.3904e-04 - acc: 1.0000 - val_loss: 1.3619 - val_acc: 0.8010
# Epoch 34/35
# 100/100 [==============================] - 0s 5ms/step - loss: 4.4896e-04 - acc: 1.0000 - val_loss: 1.3860 - val_acc: 0.8040
# Epoch 35/35
# 100/100 [==============================] - 1s 5ms/step - loss: 3.9081e-04 - acc: 1.0000 - val_loss: 1.4020 - val_acc: 0.8030

# %% [markdown]
# Проверяем модель на тестовой выборке, строим матрицу ошибок и выводим показатели метрик

# %%
prediction = model.predict(X_test, verbose=0)
Y_pred = np.argmax(prediction, axis=1)

metrics = {' accuracy' : accuracy_score(Y_test, Y_pred), 
           '       f1' : f1_score(Y_test, Y_pred, average='weighted'), 
           '   recall' : recall_score(Y_test, Y_pred, average='weighted'), 
           'precision' : precision_score(Y_test, Y_pred, average='weighted')}

confusion_martix_plot(Y_test, Y_pred, acc=metrics[' accuracy'], model_type='Perceptron', save=True)

print('Показатели метрик')
for metric, value in metrics.items():
    print(f'{metric}:\t \033[1m{value:.4f}\033[0m')
# Out:
# Показатели метрик
#  accuracy:	 0.8225
#        f1:	 0.8216
#    recall:	 0.8225
# precision:	 0.8230

# %%
# model.save_weights('perceptron_model_set_2_2.h5')

# %% [markdown]
# Выводим сводную информацию о нейронной сети:

# %%
model.summary(line_length=90)
# Out:
# Model: "sequential_73"
# __________________________________________________________________________________________
#  Layer (type)                           Output Shape                        Param #
# ==========================================================================================
#  dense_213 (Dense)                      (None, 22, 256)                     512
#
#  dense_214 (Dense)                      (None, 22, 128)                     32896
#
#  dense_215 (Dense)                      (None, 22, 64)                      8256
#
#  flatten_73 (Flatten)                   (None, 1408)                        0
#
#  dense_216 (Dense)                      (None, 256)                         360704
#
#  dense_217 (Dense)                      (None, 10)                          2570
#
# ==========================================================================================
# Total params: 404,938
# Trainable params: 404,938
# Non-trainable params: 0
# __________________________________________________________________________________________
