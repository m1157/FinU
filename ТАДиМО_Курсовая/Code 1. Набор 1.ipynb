# %% [markdown]
# # <span style="font-family:Times New Roman">Code 1. Набор 1</span>

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import pandas as pd
import numpy as np
import pickle
import time

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score, precision_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, LSTM, Dropout

from get_features import get_song_features_set_1

# %% [markdown]
# Импортируем стиль визуализации из файла `custom_mplstyle.txt`

# %%
plt.style.use('ExtraData\\custom_mplstyle.txt')

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"')

# %% [markdown]
# Импортируем необходимые списки

# %%
with open('genre_names.txt', 'r') as f:
    genre_names = f.read().split(';')

# %%
with open('genre_names_rus.txt', 'r') as f:
    genre_names_rus = f.read().split(';')

# %%
with open('genre_codes.pkl', 'rb') as f:
    genre_codes = pickle.load(f)

# %% [markdown]
# ## <span style="font-family:Times New Roman">Описание набора данных:</span>
# #### 22 параметра, 1000 аудиофайлов по 30 секунд, shape = (1000, 22)</span>
#
# |   №  |       Параметр      ||   №  |    Параметр   |
# |------|---------------------||------|---------------|
# |**1** |centroid $mean$      ||**12**|mfcc$_1$ $mean$|
# |**2** |centroid $std$       ||**13**|mfcc$_1$ $std$ |
# |**3** |rolloff $mean$       ||**14**|mfcc$_2$ $mean$|
# |**4** |rolloff $std$        ||**15**|mfcc$_2$ $std$ |
# |**5** |bandwidth $mean$     ||**16**|mfcc$_3$ $mean$|
# |**6** |bandwidth $std$      ||**17**|mfcc$_3$ $std$ |
# |**7** |flux $mean$          ||**18**|mfcc$_4$ $mean$|
# |**8** |flux $std$           ||**19**|mfcc$_4$ $std$ |
# |**9** |zero crossings $mean$||**20**|mfcc$_5$ $mean$|
# |**10**|zero crossings $std$ ||**21**|mfcc$_5$ $std$ |
# |**11**|low energy           ||**22**|tempo          |

# %% [markdown]
# ## <span style="font-family:Times New Roman">Используемые функции:</span>
#
# **1\.** `confusion_martix_plot` – график матрицы ошибок
#
# Визуализируем матрицу ошибок, которая показывает производительность модели

# %%
def confusion_martix_plot(test, pred, acc, model_type, save=True):
    cm = confusion_matrix(test, pred)

    fig, axes = plt.subplots(1, 1, figsize=(10,7))
    fig.patch.set_facecolor('#371d49')
    
    sns.heatmap(cm,
                linewidths=.5,
                linecolor="black",
                cmap=plt.cm.RdPu_r,
                annot=True, 
                fmt='g',
                annot_kws={'fontsize':18},
                xticklabels=genre_names,
                yticklabels=genre_names)
    
    plt.title(f'Accuracy = {acc:.2f}', fontsize=22, y=1.05)
    plt.xlabel('Predicted', fontsize=18)
    plt.ylabel('Real', fontsize=18)
    
    fn = file_name.split('.')[0].replace(' ', '_').lower()
    lt = '_'.join(str(x) for x in list(time.localtime())[1:-3])
    if save:
        plt.savefig(f'Images/cm_{fn}_{model_type}_{lt}.png', facecolor='#371d49', bbox_inches = 'tight', dpi = 300)
    plt.show()

# %% [markdown]
# **2\.** `plot_performance` – график обучения модели
#
# Визуализируем изменение `accuracy` и `loss` значений в процессе обучения модели

# %%
def performance_plot(hist, save=False):

    acc = hist.history['acc']
    val_acc = hist.history['val_acc']
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']
    epochs = range(len(acc))
    
    fig, axes = plt.subplots(ncols=2, figsize=(12, 4))
    
    line_1 = axes[0].plot(epochs, acc, '#18c0c4', label='Training accuracy')
    line_2 = axes[0].plot(epochs, val_acc, '#fefeff', label='Validation accuracy')
    axes[0].set_title('Training and validation accuracy')

    line_3 = axes[1].plot(epochs, loss, '#A267F5', label='Training Loss')
    line_4 = axes[1].plot(epochs, val_loss, '#f62196', label='Validation Loss')
    axes[1].set_title('Training and validation loss')

    lines = line_1 + line_2 + line_3 + line_4
    labs = [l.get_label() for l in lines]
    plt.legend(lines, labs, loc='center', bbox_to_anchor=(1.2, 0.5))
    lt = '_'.join(str(x) for x in list(time.localtime())[1:-3])
    if save:
        plt.savefig(f'Images/performance_{lt}.png', facecolor='#371d49', bbox_inches = 'tight', dpi = 300)
    plt.show()

# %% [markdown]
# **3\.** `prepare_datasets` – предобработка данных
#
# С помощью `sklearn.model_selection.train_test_split` разделяем данные в два этапа: на `train` – `validation` выборки и на `train` – `test` выборки. Также, приводим данные в трёхмерную форму:

# %%
def prepare_datasets(X, Y, split_size):
    scaler = StandardScaler()
    scaler.fit(X)
    X = scaler.transform(X)
    
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=split_size, random_state=10)
    X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=split_size, random_state=10)
    
    X_train = X_train[..., np.newaxis]
    X_val = X_val[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    
    return X_train, X_val, X_test, Y_train, Y_val, Y_test

# %% [markdown]
# ## <span style="font-family:Times New Roman">Импорт данных</span>
# Загружаем данные из файла `features_set_1.csv`

# %%
features = pd.read_csv('Sets/features_set_1.csv', index_col=[0])

# %%
features.shape
# Out:
# (1000, 23)

# %% [markdown]
# Разделяем датасет на `X` и `Y`:

# %%
X = features.drop(columns=['genre'])
Y = features['genre']

# %% [markdown]
# С помощью функции `prepare_datasets` разделяем данные на обучающую, валидационную и тестовую выборки:

# %%
X_train, X_val, X_test, Y_train, Y_val, Y_test = prepare_datasets(X, Y, 0.2)

input_shape = X_train.shape[1:]
input_shape
# Out:
# (22, 1)

# %% [markdown]
# ## <span style="font-family:Times New Roman">1\. CNN (Convolutional Neural Network)</span>
# Функция `CNN_model` содержит архитектуру CNN-модели:

# %%
def CNN_model(input_shape):

    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(filters=128, kernel_size=4, activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPooling1D(pool_size=1),
        tf.keras.layers.Dropout(0.3),
        
        tf.keras.layers.Conv1D(filters=256, kernel_size=4, activation='relu'),
        tf.keras.layers.MaxPooling1D(pool_size=1),        
        tf.keras.layers.Dropout(0.3),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax', 
                              kernel_regularizer=tf.keras.regularizers.L1(l=0.1)
                             )
    ])

    return model

# %% [markdown]
# ### <span style="font-family:Times New Roman">Компилируем и обучаем модель</span>
# * Оптимизатор: **RMSprop**, learning rate = $1e-2$
# * Функция потерь (Loss function): **SparseCategoricalCrossentropy**  – для двух и более классов целовчисленных меток
# * Количество эпох: **40**
# * Размер батча: **32**
# * Для каждой эпохи рассчитывается `loss`, `accuracy` для обучающей и валидационных выборок

# %%
model = CNN_model(input_shape)

model.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01),
              loss='sparse_categorical_crossentropy',
              metrics = ['acc'])

history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=40, batch_size=32)

performance_plot(history)
# Out:
# Epoch 1/40
# 20/20 [==============================] - 1s 19ms/step - loss: 7.4366 - acc: 0.2375 - val_loss: 3.4693 - val_acc: 0.4250
# Epoch 2/40
# 20/20 [==============================] - 0s 12ms/step - loss: 3.4662 - acc: 0.3562 - val_loss: 3.4235 - val_acc: 0.2900
# Epoch 3/40
# 20/20 [==============================] - 0s 13ms/step - loss: 3.2318 - acc: 0.3781 - val_loss: 3.0818 - val_acc: 0.4200
# Epoch 4/40
# 20/20 [==============================] - 0s 13ms/step - loss: 3.0709 - acc: 0.4266 - val_loss: 2.9855 - val_acc: 0.4550
# Epoch 5/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.9328 - acc: 0.4812 - val_loss: 2.5473 - val_acc: 0.5550
# Epoch 6/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.7038 - acc: 0.5531 - val_loss: 2.5108 - val_acc: 0.5500
# Epoch 7/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.6285 - acc: 0.5688 - val_loss: 2.4191 - val_acc: 0.6150
# Epoch 8/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.5364 - acc: 0.6078 - val_loss: 2.3874 - val_acc: 0.6400
# Epoch 9/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.4741 - acc: 0.6359 - val_loss: 2.3652 - val_acc: 0.6500
# Epoch 10/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.3932 - acc: 0.6531 - val_loss: 2.3871 - val_acc: 0.6700
# Epoch 11/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.4368 - acc: 0.6375 - val_loss: 2.3510 - val_acc: 0.6100
# Epoch 12/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.3608 - acc: 0.6609 - val_loss: 2.4651 - val_acc: 0.6050
# Epoch 13/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.2986 - acc: 0.6906 - val_loss: 2.3543 - val_acc: 0.6400
# Epoch 14/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.2554 - acc: 0.7063 - val_loss: 2.3687 - val_acc: 0.6400
# Epoch 15/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.2740 - acc: 0.7141 - val_loss: 2.3214 - val_acc: 0.6300
# Epoch 16/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.1898 - acc: 0.7437 - val_loss: 2.4712 - val_acc: 0.6150
# Epoch 17/40
# 20/20 [==============================] - 0s 13ms/step - loss: 2.1856 - acc: 0.7094 - val_loss: 2.3205 - val_acc: 0.6550
# Epoch 18/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.1413 - acc: 0.7344 - val_loss: 2.3324 - val_acc: 0.6600
# Epoch 19/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.1064 - acc: 0.7547 - val_loss: 2.4854 - val_acc: 0.5800
# Epoch 20/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.0763 - acc: 0.7719 - val_loss: 2.3688 - val_acc: 0.6350
# Epoch 21/40
# 20/20 [==============================] - 0s 13ms/step - loss: 2.1300 - acc: 0.7672 - val_loss: 2.3811 - val_acc: 0.6200
# Epoch 22/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.9894 - acc: 0.7891 - val_loss: 2.3061 - val_acc: 0.6400
# Epoch 23/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.9817 - acc: 0.8047 - val_loss: 2.3954 - val_acc: 0.6550
# Epoch 24/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.0289 - acc: 0.7875 - val_loss: 2.3247 - val_acc: 0.6550
# Epoch 25/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.9889 - acc: 0.7906 - val_loss: 2.3899 - val_acc: 0.6450
# Epoch 26/40
# 20/20 [==============================] - 0s 12ms/step - loss: 2.0203 - acc: 0.7812 - val_loss: 2.4336 - val_acc: 0.6700
# Epoch 27/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.9835 - acc: 0.7859 - val_loss: 2.4284 - val_acc: 0.6500
# Epoch 28/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.9521 - acc: 0.8109 - val_loss: 2.4039 - val_acc: 0.6300
# Epoch 29/40
# 20/20 [==============================] - 0s 13ms/step - loss: 1.8989 - acc: 0.8234 - val_loss: 2.3006 - val_acc: 0.6600
# Epoch 30/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.9244 - acc: 0.8313 - val_loss: 2.5092 - val_acc: 0.6600
# Epoch 31/40
# 20/20 [==============================] - 0s 13ms/step - loss: 1.8888 - acc: 0.8359 - val_loss: 2.4370 - val_acc: 0.6900
# Epoch 32/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.9134 - acc: 0.8172 - val_loss: 2.5043 - val_acc: 0.6700
# Epoch 33/40
# 20/20 [==============================] - 0s 13ms/step - loss: 1.8466 - acc: 0.8547 - val_loss: 2.4559 - val_acc: 0.6550
# Epoch 34/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.8294 - acc: 0.8578 - val_loss: 2.3693 - val_acc: 0.6700
# Epoch 35/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.8856 - acc: 0.8156 - val_loss: 2.3703 - val_acc: 0.6350
# Epoch 36/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.8544 - acc: 0.8313 - val_loss: 2.4736 - val_acc: 0.6450
# Epoch 37/40
# 20/20 [==============================] - 0s 13ms/step - loss: 1.8496 - acc: 0.8297 - val_loss: 2.6406 - val_acc: 0.6500
# Epoch 38/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.8348 - acc: 0.8531 - val_loss: 2.5571 - val_acc: 0.6650
# Epoch 39/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.8021 - acc: 0.8641 - val_loss: 2.5779 - val_acc: 0.6550
# Epoch 40/40
# 20/20 [==============================] - 0s 12ms/step - loss: 1.7848 - acc: 0.8734 - val_loss: 2.7655 - val_acc: 0.6450

# %% [markdown]
# Проверяем модель на тестовой выборке, строим матрицу ошибок и выводим показатели метрик

# %%
prediction = model.predict(X_test, verbose=0)
Y_pred = np.argmax(prediction, axis=1)

metrics = {' accuracy' : accuracy_score(Y_test, Y_pred), 
           '       f1' : f1_score(Y_test, Y_pred, average='weighted'), 
           '   recall' : recall_score(Y_test, Y_pred, average='weighted'), 
           'precision' : precision_score(Y_test, Y_pred, average='weighted')}

confusion_martix_plot(Y_test, Y_pred, acc=metrics[' accuracy'], model_type='CNN', save=False)

print('Показатели метрик')
for metric, value in metrics.items():
    print(f'{metric}:\t \033[1m{value:.4f}\033[0m')
# Out:
# Показатели метрик
#  accuracy:	 0.6188
#        f1:	 0.6203
#    recall:	 0.6188
# precision:	 0.6492

# %% [markdown]
# Выводим сводную информацию о нейронной сети:

# %%
model.summary(line_length=90)
# Out:
# Model: "sequential_12"
# __________________________________________________________________________________________
#  Layer (type)                           Output Shape                        Param #
# ==========================================================================================
#  conv1d_25 (Conv1D)                     (None, 19, 128)                     640
#
#  max_pooling1d_25 (MaxPooling1D)        (None, 19, 128)                     0
#
#  dropout_25 (Dropout)                   (None, 19, 128)                     0
#
#  conv1d_26 (Conv1D)                     (None, 16, 256)                     131328
#
#  max_pooling1d_26 (MaxPooling1D)        (None, 16, 256)                     0
#
#  dropout_26 (Dropout)                   (None, 16, 256)                     0
#
#  flatten_12 (Flatten)                   (None, 4096)                        0
#
#  dense_24 (Dense)                       (None, 256)                         1048832
#
#  dense_25 (Dense)                       (None, 10)                          2570
#
# ==========================================================================================
# Total params: 1,183,370
# Trainable params: 1,183,370
# Non-trainable params: 0
# __________________________________________________________________________________________

# %% [markdown]
# ## <span style="font-family:Times New Roman">2\. RNN (Recurrent Neural Network)</span>
# Функция `RNN_model` содержит архитектуру RNN-модели:

# %%
def RNN_model(input_shape):

    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(64, return_sequences=True, input_shape=input_shape),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    return model

# %% [markdown]
# ### <span style="font-family:Times New Roman">Компилируем и обучаем модель</span>
# * Оптимизатор: **RMSprop**, learning rate = $1e-2$
# * Функция потерь (Loss function): **SparseCategoricalCrossentropy**  – для двух и более классов целовчисленных меток
# * Количество эпох: **30**
# * Размер батча: **32**
# * Для каждой эпохи рассчитывается `loss`, `accuracy` для обучающей и валидационных выборок

# %%
model = RNN_model(input_shape)

model.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01),
                 loss='sparse_categorical_crossentropy',
                 metrics = ['acc']
                 )

history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=30, batch_size=32)

performance_plot(history)
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_19 (LSTM)              (None, 22, 64)            16896
#
#  dropout_43 (Dropout)        (None, 22, 64)            0
#
#  flatten_26 (Flatten)        (None, 1408)              0
#
#  dense_39 (Dense)            (None, 10)                14090
#
# =================================================================
# Total params: 30,986
# Trainable params: 30,986
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 20/20 [==============================] - 2s 38ms/step - loss: 1.7658 - acc: 0.3375 - val_loss: 1.3191 - val_acc: 0.5350
# Epoch 2/30
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3760 - acc: 0.5094 - val_loss: 1.2019 - val_acc: 0.5550
# Epoch 3/30
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1993 - acc: 0.5578 - val_loss: 1.1748 - val_acc: 0.5450
# Epoch 4/30
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1374 - acc: 0.5781 - val_loss: 1.0713 - val_acc: 0.5800
# Epoch 5/30
# 20/20 [==============================] - 0s 7ms/step - loss: 1.0322 - acc: 0.6266 - val_loss: 1.0469 - val_acc: 0.5950
# Epoch 6/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9857 - acc: 0.6422 - val_loss: 1.0308 - val_acc: 0.6300
# Epoch 7/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8992 - acc: 0.6578 - val_loss: 0.9796 - val_acc: 0.6200
# Epoch 8/30
# 20/20 [==============================] - 0s 8ms/step - loss: 0.8649 - acc: 0.6984 - val_loss: 0.9773 - val_acc: 0.6450
# Epoch 9/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8062 - acc: 0.6938 - val_loss: 1.0407 - val_acc: 0.6450
# Epoch 10/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7593 - acc: 0.7266 - val_loss: 0.9472 - val_acc: 0.6350
# Epoch 11/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7381 - acc: 0.7156 - val_loss: 1.0592 - val_acc: 0.6450
# Epoch 12/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6665 - acc: 0.7547 - val_loss: 0.9286 - val_acc: 0.6550
# Epoch 13/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6603 - acc: 0.7859 - val_loss: 0.9570 - val_acc: 0.6600
# Epoch 14/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6031 - acc: 0.7734 - val_loss: 1.0331 - val_acc: 0.6600
# Epoch 15/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6094 - acc: 0.7688 - val_loss: 1.1976 - val_acc: 0.6300
# Epoch 16/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5121 - acc: 0.8281 - val_loss: 1.0215 - val_acc: 0.6550
# Epoch 17/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4851 - acc: 0.8297 - val_loss: 1.1268 - val_acc: 0.6750
# Epoch 18/30
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4379 - acc: 0.8438 - val_loss: 1.2756 - val_acc: 0.6500
# Epoch 19/30
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4172 - acc: 0.8641 - val_loss: 1.2599 - val_acc: 0.6500
# Epoch 20/30
# 20/20 [==============================] - 0s 8ms/step - loss: 0.3667 - acc: 0.8703 - val_loss: 1.2783 - val_acc: 0.6150
# Epoch 21/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.3351 - acc: 0.8750 - val_loss: 1.3102 - val_acc: 0.6650
# Epoch 22/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.3032 - acc: 0.8797 - val_loss: 1.3121 - val_acc: 0.6650
# Epoch 23/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.2404 - acc: 0.9187 - val_loss: 1.4726 - val_acc: 0.6400
# Epoch 24/30
# 20/20 [==============================] - 0s 8ms/step - loss: 0.2386 - acc: 0.9109 - val_loss: 1.5757 - val_acc: 0.6200
# Epoch 25/30
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1695 - acc: 0.9438 - val_loss: 1.5039 - val_acc: 0.6350
# Epoch 26/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1906 - acc: 0.9297 - val_loss: 1.8103 - val_acc: 0.6450
# Epoch 27/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1453 - acc: 0.9453 - val_loss: 1.4949 - val_acc: 0.6650
# Epoch 28/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1373 - acc: 0.9469 - val_loss: 1.6348 - val_acc: 0.6650
# Epoch 29/30
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1127 - acc: 0.9672 - val_loss: 1.6934 - val_acc: 0.6800
# Epoch 30/30
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1221 - acc: 0.9578 - val_loss: 1.5846 - val_acc: 0.6600

# %% [markdown]
# Проверяем модель на тестовой выборке, строим матрицу ошибок и выводим показатели метрик

# %%
prediction = model.predict(X_test, verbose=0)
Y_pred = np.argmax(prediction, axis=1)

metrics = {' accuracy' : accuracy_score(Y_test, Y_pred), 
           '       f1' : f1_score(Y_test, Y_pred, average='weighted'), 
           '   recall' : recall_score(Y_test, Y_pred, average='weighted'), 
           'precision' : precision_score(Y_test, Y_pred, average='weighted')}

confusion_martix_plot(Y_test, Y_pred, acc=metrics[' accuracy'], model_type='RNN', save=False)

print('Показатели метрик')
for metric, value in metrics.items():
    print(f'{metric}:\t \033[1m{value:.4f}\033[0m')
# Out:
# Показатели метрик
#  accuracy:	 0.5750
#        f1:	 0.5782
#    recall:	 0.5750
# precision:	 0.5971

# %% [markdown]
# Выводим сводную информацию о нейронной сети:

# %%
model.summary(line_length=90)
# Out:
# Model: "sequential_12"
# __________________________________________________________________________________________
#  Layer (type)                           Output Shape                        Param #
# ==========================================================================================
#  conv1d_25 (Conv1D)                     (None, 19, 128)                     640
#
#  max_pooling1d_25 (MaxPooling1D)        (None, 19, 128)                     0
#
#  dropout_25 (Dropout)                   (None, 19, 128)                     0
#
#  conv1d_26 (Conv1D)                     (None, 16, 256)                     131328
#
#  max_pooling1d_26 (MaxPooling1D)        (None, 16, 256)                     0
#
#  dropout_26 (Dropout)                   (None, 16, 256)                     0
#
#  flatten_12 (Flatten)                   (None, 4096)                        0
#
#  dense_24 (Dense)                       (None, 256)                         1048832
#
#  dense_25 (Dense)                       (None, 10)                          2570
#
# ==========================================================================================
# Total params: 1,183,370
# Trainable params: 1,183,370
# Non-trainable params: 0
# __________________________________________________________________________________________

# %% [markdown]
# ## <span style="font-family:Times New Roman">3\. Multilayer Perceptron</span>
# Функция `Perceptron_model` содержит архитектуру многослойного перцептрона:

# %%
def Perceptron_model(input_shape):

    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(64, activation='relu', input_shape=input_shape),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    
    return model

# %% [markdown]
# ### <span style="font-family:Times New Roman">Компилируем и обучаем модель</span>
# * Оптимизатор: **adam**
# * Функция потерь (Loss function): **SparseCategoricalCrossentropy**  – для двух и более классов целовчисленных меток
# * Количество эпох: **40**
# * Размер батча: **32**
# * Для каждой эпохи рассчитывается `loss`, `accuracy` для обучающей и валидационных выборок

# %%
model = Perceptron_model(input_shape)

model.compile(optimizer = 'adam',
                 loss='sparse_categorical_crossentropy',
                 metrics = ['acc']
                 )

history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val),
                    epochs=40, batch_size=32)

performance_plot(history)
# Out:
# Epoch 1/40
# 20/20 [==============================] - 1s 15ms/step - loss: 1.7620 - acc: 0.3734 - val_loss: 1.1837 - val_acc: 0.5950
# Epoch 2/40
# 20/20 [==============================] - 0s 8ms/step - loss: 1.1581 - acc: 0.5859 - val_loss: 1.1003 - val_acc: 0.6200
# Epoch 3/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9488 - acc: 0.6516 - val_loss: 1.0346 - val_acc: 0.6000
# Epoch 4/40
# 20/20 [==============================] - 0s 9ms/step - loss: 0.8332 - acc: 0.7109 - val_loss: 1.0514 - val_acc: 0.6450
# Epoch 5/40
# 20/20 [==============================] - 0s 9ms/step - loss: 0.7510 - acc: 0.7281 - val_loss: 0.9563 - val_acc: 0.6750
# Epoch 6/40
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6906 - acc: 0.7469 - val_loss: 1.0108 - val_acc: 0.6550
# Epoch 7/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6366 - acc: 0.7703 - val_loss: 1.0233 - val_acc: 0.6400
# Epoch 8/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5321 - acc: 0.8156 - val_loss: 1.0778 - val_acc: 0.6800
# Epoch 9/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5426 - acc: 0.8188 - val_loss: 1.0413 - val_acc: 0.6750
# Epoch 10/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4292 - acc: 0.8687 - val_loss: 1.0702 - val_acc: 0.6600
# Epoch 11/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4008 - acc: 0.8656 - val_loss: 1.2219 - val_acc: 0.6600
# Epoch 12/40
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3740 - acc: 0.8766 - val_loss: 1.2083 - val_acc: 0.6850
# Epoch 13/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.3421 - acc: 0.8703 - val_loss: 1.1856 - val_acc: 0.6800
# Epoch 14/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.3329 - acc: 0.8906 - val_loss: 1.0938 - val_acc: 0.6850
# Epoch 15/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.2852 - acc: 0.9141 - val_loss: 1.1955 - val_acc: 0.6750
# Epoch 16/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.2722 - acc: 0.9125 - val_loss: 1.3037 - val_acc: 0.6550
# Epoch 17/40
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2414 - acc: 0.9062 - val_loss: 1.4603 - val_acc: 0.6800
# Epoch 18/40
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2326 - acc: 0.9250 - val_loss: 1.2898 - val_acc: 0.6600
# Epoch 19/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1685 - acc: 0.9453 - val_loss: 1.3683 - val_acc: 0.6950
# Epoch 20/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1468 - acc: 0.9563 - val_loss: 1.4067 - val_acc: 0.7050
# Epoch 21/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0945 - acc: 0.9719 - val_loss: 1.4112 - val_acc: 0.6950
# Epoch 22/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0734 - acc: 0.9797 - val_loss: 1.3923 - val_acc: 0.6850
# Epoch 23/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1011 - acc: 0.9734 - val_loss: 1.6349 - val_acc: 0.6850
# Epoch 24/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1075 - acc: 0.9688 - val_loss: 1.6689 - val_acc: 0.6750
# Epoch 25/40
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1116 - acc: 0.9641 - val_loss: 1.7879 - val_acc: 0.7100
# Epoch 26/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0963 - acc: 0.9672 - val_loss: 1.6229 - val_acc: 0.7150
# Epoch 27/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1003 - acc: 0.9656 - val_loss: 1.6104 - val_acc: 0.6650
# Epoch 28/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0538 - acc: 0.9906 - val_loss: 1.7050 - val_acc: 0.7150
# Epoch 29/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0482 - acc: 0.9875 - val_loss: 1.7233 - val_acc: 0.6850
# Epoch 30/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0435 - acc: 0.9875 - val_loss: 1.7827 - val_acc: 0.7150
# Epoch 31/40
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0394 - acc: 0.9891 - val_loss: 1.8198 - val_acc: 0.7000
# Epoch 32/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0540 - acc: 0.9859 - val_loss: 1.8154 - val_acc: 0.6800
# Epoch 33/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1004 - acc: 0.9672 - val_loss: 2.0181 - val_acc: 0.6900
# Epoch 34/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1513 - acc: 0.9719 - val_loss: 2.0547 - val_acc: 0.6700
# Epoch 35/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.2569 - acc: 0.9438 - val_loss: 2.0580 - val_acc: 0.6600
# Epoch 36/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1744 - acc: 0.9484 - val_loss: 1.8375 - val_acc: 0.6550
# Epoch 37/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1196 - acc: 0.9672 - val_loss: 1.6907 - val_acc: 0.6700
# Epoch 38/40
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0612 - acc: 0.9812 - val_loss: 1.5617 - val_acc: 0.6800
# Epoch 39/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0355 - acc: 0.9906 - val_loss: 1.7304 - val_acc: 0.7050
# Epoch 40/40
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0323 - acc: 0.9906 - val_loss: 1.9115 - val_acc: 0.6900

# %% [markdown]
# Проверяем модель на тестовой выборке, строим матрицу ошибок и выводим показатели метрик

# %%
prediction = model.predict(X_test, verbose=0)
Y_pred = np.argmax(prediction, axis=1)

metrics = {' accuracy' : accuracy_score(Y_test, Y_pred), 
           '       f1' : f1_score(Y_test, Y_pred, average='weighted'), 
           '   recall' : recall_score(Y_test, Y_pred, average='weighted'), 
           'precision' : precision_score(Y_test, Y_pred, average='weighted')}

confusion_martix_plot(Y_test, Y_pred, acc=metrics[' accuracy'], model_type='Perceptron', save=False)

print('Показатели метрик')
for metric, value in metrics.items():
    print(f'{metric}:\t \033[1m{value:.4f}\033[0m')
# Out:
# Показатели метрик
#  accuracy:	 0.6375
#        f1:	 0.6246
#    recall:	 0.6375
# precision:	 0.6330

# %% [markdown]
# Выводим сводную информацию о нейронной сети:

# %%
model.summary(line_length=90)
# Out:
# Model: "sequential_12"
# __________________________________________________________________________________________
#  Layer (type)                           Output Shape                        Param #
# ==========================================================================================
#  conv1d_25 (Conv1D)                     (None, 19, 128)                     640
#
#  max_pooling1d_25 (MaxPooling1D)        (None, 19, 128)                     0
#
#  dropout_25 (Dropout)                   (None, 19, 128)                     0
#
#  conv1d_26 (Conv1D)                     (None, 16, 256)                     131328
#
#  max_pooling1d_26 (MaxPooling1D)        (None, 16, 256)                     0
#
#  dropout_26 (Dropout)                   (None, 16, 256)                     0
#
#  flatten_12 (Flatten)                   (None, 4096)                        0
#
#  dense_24 (Dense)                       (None, 256)                         1048832
#
#  dense_25 (Dense)                       (None, 10)                          2570
#
# ==========================================================================================
# Total params: 1,183,370
# Trainable params: 1,183,370
# Non-trainable params: 0
# __________________________________________________________________________________________
