# %% [markdown]
# # <span style="font-family:Times New Roman">Code 5. Музыкальные рекомендации</span>

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import pandas as pd
import numpy as np
import glob
import pickle
import IPython

from scipy.spatial.distance import cosine, cityblock, correlation, canberra, chebyshev, euclidean

from get_features import get_song_features_set_1, get_song_name

# %% [markdown]
# Импортируем необходимые списки

# %%
with open('ExtraData\\gtzan_track_names.pkl', 'rb') as f:
    gtzan_track_names = pickle.load(f)

# %% [markdown]
# * **Canberra Distance**: Метрика Канберры `canberra`
# * **Chebyshev Distance**: Расстояние Чебышёва `chebyshev`
# * **Manhattan Distance**: Расстояние городских кварталов, манхэттенское `cityblock`
# * **Correlation Distance**: Корреляция по расстоянию `correlation`
# * **Cosine Distance**: Косинусное расстояние `cosine`
# * **Euclidean Distance**: Евклидово расстояние `euclidean`

# %% [markdown]
# * Метрика Канберры определяется как
# $$d(u,v) = \sum_i{\frac{|u_i - v_i|}{|u_i|+|v_i|}}$$
#
# * Расстояние Чебышёва определяется как
# $$d(u,v) = \max_i|u_i - v_i|$$
#
# * Расстояние городских кварталов определяется как
# $$d(u,v) = \sum_i|u_i - v_i|$$
#
# * Корреляция по расстоянию определяется как
# $$d(u,v) = 1 - \frac{|u - \bar{u}|\cdot|v - \bar{v}|}{\|u - \bar{u}\|_2\|v - \bar{v}\|_2}$$
#
# * Косинусное расстояние определяется как
# $$d(u,v) = 1 - \frac{u\cdot v}{\|u\|_2\|v\|_2}$$
#
# * Евклидово расстояние определяется как
# $$d(u,v) = \|u-v\|_2$$
#
# <!-- К Manhattan ближе всего Euclidean, дальше Chebyshev, потом вместе Cosine и Correlation, последнее - Canberra\
# **Canberra – Cosine/Correlation – Manhattan/Euclidean/Chebyshev** -->

# %%
distances = [cosine, cityblock, correlation, canberra, chebyshev, euclidean]

distances_names = ['Cosine Distance', 'Manhattan Distance',  
                   'Correlation Distance', 'Canberra Distance', 
                   'Chebyshev Distance', 'Euclidean Distance']

# %% [markdown]
# Список аудиофайлов из набора `GTZAN` (1):

# %%
path_default = 'C:\\Users\\micha\\OneDrive\\Рабочий стол\\Курсовая\\genres_original\\' 
files_default = glob.glob(path_default + "*\\*.wav")

# %% [markdown]
# Список аудиофайлов, добавленных вручную (2):

# %%
path = 'C:\\Users\\micha\\OneDrive\\Рабочий стол\\Курсовая\\Music'
files = glob.glob(path + "*\\*.wav")

# %% [markdown]
# Словарь с названиями аудиофайлов и путями к ним:

# %%
path_name_dict = dict()
for path in files:
    path_name_dict[get_song_name(path)] = path
    
for i, path in enumerate(files_default):
    path_name_dict[list(gtzan_track_names.values())[i]] = path

# %% [markdown]
# ## <span style="font-family:Times New Roman">Используемые функции:</span>
#
# **1\.** `add_features` – добавить новые трек(и)
#
# Если в наборе нет композиции, то рассчитываем для нее характеристики и добавляем в набор `features_set_enlarged.csv`

# %%
def add_features(features, files_to_add):
    for file in files_to_add:
        name = get_song_name(file)
        if not name in features.index:
            print(name)
            records = get_song_features_set_1(file)
            records['genre'] = 'Unknown'
            features.loc[name] = records
            
    features.to_csv('Sets\\features_set_enlarged.csv')
    return features

# %% [markdown]
# **2\.** `delete_features` – удалить трек(и)
#
# Удаляем композиции и их характеристики из набора `features_set_enlarged.csv`

# %%
def delete_features(features, files_to_delete):
    for file in files_to_delete:
        name = get_song_name(file)
        if name in features.index:
            features.drop(index=name, inplace=True)
            
    features.to_csv('Sets\\features_set_enlarged.csv')
    return features

# %% [markdown]
# **3\.** `get_distance` – рассчет расстояний
#
# Рассчитываем расстояние типа `distance` одной композиций с остальными, находящимися в `df`

# %%
def get_distance(df, features, distance):
    dist = np.array([distance(A, features) for A in df.values]).round(5)
    return dist

# %% [markdown]
# **4\.** `get_distance` – вывод аудио-объекта
#
# С помощью `IPython` выводим интерфейс с возможностью воспроизведения звукового файла

# %%
def listen_audio(track_name):
    print(track_name)
    IPython.display.display(IPython.display.Audio(path_name_dict[track_name]))

# %% [markdown]
# **4\.** `find_closest` – рекомендация на основе музыкальной "близости"
#
#
# На основе музыкальных характеристик функция отбирает `n` наиболее близких к конкретной композиции аудиофайлов. Есть возможность передать параметр `sorted_distance`, определяющий тип расстояния, по которому будет проводиться сортировка. Также, есть возможность передать параметр `audio_output`, который при значении  `True` позволяет прослушать композиции из списка рекомендаций.

# %%
def find_closest(df, track_name, n=10, sorted_distance=None, audio_output=False):
    df = df.copy()
    final_df = df[['genre']].copy()
    df.drop(columns=['genre'], inplace=True)
    
    track_name = get_song_name(track_name)
    track_idx = np.where(df.index == track_name)[0][0]
    track_features = df.iloc[track_idx].values
    
    for i, distance in enumerate(distances):
        final_df[distances_names[i]] = get_distance(df, track_features, distance)
        final_df[distances_names[i]] = final_df[distances_names[i]].rank()
    
    if sorted_distance == None:
        final_df['Rank'] = final_df.drop(columns=['genre']).sum(1)
        sorted_distance = 'Rank' 
    
    final_df.drop(index=[track_name], inplace=True)
    final_df.sort_values(sorted_distance, ascending=True, inplace=True)
    
    if audio_output:
        listen_audio(track_name)
        print('_' * len(track_name))
        for track in final_df.head(n).index:
            listen_audio(track)

    return final_df.head(n)

# %% [markdown]
# ## <span style="font-family:Times New Roman">Подбор рекомендаций</span>
# Загружаем данные из файла `features_set_enlarged.csv`, где хранятся файлы из наборов (1) и (2)

# %%
features = pd.read_csv('Sets\\features_set_enlarged.csv', index_col=[0])

# %%
features.shape
# Out:
# (1099, 23)

# %%
features.iloc[-7:]
# Out:
#                                           spectral_centroid_mean  \
# Nirvana – Come As You Are.wav                        2474.668922
# Queen - Another One Bites The Dust.wav               2293.723541
# Queen – Don t Stop Me Now.wav                        3123.289848
# Машина времени – Поворот.wav                         2372.028293
# Муслим Магомаев – Лучший город Земли.wav             1951.150470
# Павел Кашин – Барышня.wav                            2902.450969
# Сергей Трофимов – Ветер в голове.wav                 2045.229478
#
#                                           spectral_centroid_std  \
# Nirvana – Come As You Are.wav                        659.607128
# Queen - Another One Bites The Dust.wav              1063.086967
# Queen – Don t Stop Me Now.wav                        853.717043
# Машина времени – Поворот.wav                         740.031912
# Муслим Магомаев – Лучший город Земли.wav             601.885701
# Павел Кашин – Барышня.wav                            795.214207
# Сергей Трофимов – Ветер в голове.wav                 712.637558
#
#                                           spectral_rolloff_mean  \
# Nirvana – Come As You Are.wav                       5315.818056
# Queen - Another One Bites The Dust.wav              4558.332935
# Queen – Don t Stop Me Now.wav                       5982.772330
# Машина времени – Поворот.wav                        5065.596323
# Муслим Магомаев – Лучший город Земли.wav            3866.374047
# Павел Кашин – Барышня.wav                           6195.558893
# Сергей Трофимов – Ветер в голове.wav                4313.863662
#
#                                           spectral_rolloff_std  \
# Nirvana – Come As You Are.wav                      1466.892498
# Queen - Another One Bites The Dust.wav             2089.505858
# Queen – Don t Stop Me Now.wav                      1412.974976
# Машина времени – Поворот.wav                       1557.238450
# Муслим Магомаев – Лучший город Земли.wav           1347.705064
# Павел Кашин – Барышня.wav                          1163.851443
# Сергей Трофимов – Ветер в голове.wav               1436.883564
#
#                                           spectral_bandwidth_mean  \
# Nirvana – Come As You Are.wav                         2526.429249
# Queen - Another One Bites The Dust.wav                2295.501358
# Queen – Don t Stop Me Now.wav                         2587.507419
# Машина времени – Поворот.wav                          2560.645165
# Муслим Магомаев – Лучший город Земли.wav              2042.850856
# Павел Кашин – Барышня.wav                             2766.880215
# Сергей Трофимов – Ветер в голове.wav                  2247.862449
#
#                                           spectral_bandwidth_std  \
# Nirvana – Come As You Are.wav                         496.273741
# Queen - Another One Bites The Dust.wav                646.230588
# Queen – Don t Stop Me Now.wav                         347.275689
# Машина времени – Поворот.wav                          464.045756
# Муслим Магомаев – Лучший город Земли.wav              533.338694
# Павел Кашин – Барышня.wav                             287.846211
# Сергей Трофимов – Ветер в голове.wav                  455.874634
#
#                                           spectral_flux_mean  \
# Nirvana – Come As You Are.wav                       1.111476
# Queen - Another One Bites The Dust.wav              1.959408
# Queen – Don t Stop Me Now.wav                       1.321040
# Машина времени – Поворот.wav                        1.274116
# Муслим Магомаев – Лучший город Земли.wav            1.251057
# Павел Кашин – Барышня.wav                           1.363239
# Сергей Трофимов – Ветер в голове.wav                1.642617
#
#                                           spectral_flux_std  \
# Nirvana – Come As You Are.wav                      1.154441
# Queen - Another One Bites The Dust.wav             3.537536
# Queen – Don t Stop Me Now.wav                      1.206144
# Машина времени – Поворот.wav                       1.698707
# Муслим Магомаев – Лучший город Земли.wav           1.020806
# Павел Кашин – Барышня.wav                          1.491126
# Сергей Трофимов – Ветер в голове.wav               2.260282
#
#                                           zero_crossings_mean  \
# Nirvana – Come As You Are.wav                        0.110180
# Queen - Another One Bites The Dust.wav               0.111625
# Queen – Don t Stop Me Now.wav                        0.172598
# Машина времени – Поворот.wav                         0.090955
# Муслим Магомаев – Лучший город Земли.wav             0.101820
# Павел Кашин – Барышня.wav                            0.134912
# Сергей Трофимов – Ветер в голове.wav                 0.085485
#
#                                           zero_crossings_std  ...  mfcc_1_std  \
# Nirvana – Come As You Are.wav                       0.046021  ...   99.446320
# Queen - Another One Bites The Dust.wav              0.081036  ...  129.503006
# Queen – Don t Stop Me Now.wav                       0.079406  ...   97.056473
# Машина времени – Поворот.wav                        0.047057  ...   87.683746
# Муслим Магомаев – Лучший город Земли.wav            0.038793  ...  121.498619
# Павел Кашин – Барышня.wav                           0.083057  ...   87.736237
# Сергей Трофимов – Ветер в голове.wav                0.044973  ...   87.028374
#
#                                           mfcc_2_mean  mfcc_2_std  \
# Nirvana – Come As You Are.wav               81.105202   29.781263
# Queen - Another One Bites The Dust.wav      90.927994   50.710899
# Queen – Don t Stop Me Now.wav               52.126919   30.243607
# Машина времени – Поворот.wav                80.378250   25.242746
# Муслим Магомаев – Лучший город Земли.wav   102.824165   31.248932
# Павел Кашин – Барышня.wav                   65.057190   23.172899
# Сергей Трофимов – Ветер в голове.wav        96.691628   30.204744
#
#                                           mfcc_3_mean  mfcc_3_std  \
# Nirvana – Come As You Are.wav                1.752125   23.487410
# Queen - Another One Bites The Dust.wav      -7.161055   38.195992
# Queen – Don t Stop Me Now.wav              -18.115164   23.434286
# Машина времени – Поворот.wav                 0.636832   17.350782
# Муслим Магомаев – Лучший город Земли.wav   -14.733639   19.932064
# Павел Кашин – Барышня.wav                    4.281864   15.337262
# Сергей Трофимов – Ветер в голове.wav        -5.944005   21.214643
#
#                                           mfcc_4_mean  mfcc_4_std  \
# Nirvana – Come As You Are.wav               36.848774   15.000340
# Queen - Another One Bites The Dust.wav      29.677502   23.904655
# Queen – Don t Stop Me Now.wav               25.737743   16.249634
# Машина времени – Поворот.wav                29.432810   16.154690
# Муслим Магомаев – Лучший город Земли.wav    31.363176   13.779013
# Павел Кашин – Барышня.wav                   26.544344   13.661721
# Сергей Трофимов – Ветер в голове.wav        39.032768   16.617081
#
#                                           mfcc_5_mean  mfcc_5_std    genre
# Nirvana – Come As You Are.wav                8.589679   10.315143  Unknown
# Queen - Another One Bites The Dust.wav       7.839751   16.931730  Unknown
# Queen – Don t Stop Me Now.wav                4.785786   12.215717  Unknown
# Машина времени – Поворот.wav                 7.620935   12.633163  Unknown
# Муслим Магомаев – Лучший город Земли.wav    -5.088217   16.413363  Unknown
# Павел Кашин – Барышня.wav                    3.377597   11.354586  Unknown
# Сергей Трофимов – Ветер в голове.wav         4.931193   14.699624  Unknown
#
# [7 rows x 23 columns]

# %%
# %%time
find_closest(df=features, 
             track_name='Машина времени – Поворот.wav', 
             n=15, 
#              sorted_distance='Canberra Distance',
             audio_output=False)
# Out:
# Wall time: 128 ms
#                                                       genre  Cosine Distance  \
# No Doubt – Dont Speak.wav                           Unknown             26.0
# Modjo – Lady (Hear Me Tonight).wav                  Unknown             35.0
# Earth Wind and Fire – Sing a Song                     Disco              9.5
# Led Zeppelin – Night Flight                            Rock              8.0
# Dexter Gordon – Willow Weep For Me                     Jazz             17.0
# Nirvana – Come As You Are.wav                       Unknown             49.0
# David Christie – Saddle Up                            Disco             24.0
# Gregory Isaacs – John Law                            Reggae              3.0
# Ini Kamoze – Here Comes The Hot Stepper(remix)       Reggae             32.5
# Dennis Brown – It's Magic                            Reggae             64.0
# Maroon 5 – Sugar.wav                                Unknown             60.0
# Dexter Gordon – Our Love Is Here To Stay               Jazz             49.0
# PIZZA – Романс.wav                                  Unknown             60.0
# Ladysmith Black Mambazo – Leaning On The Everla...      Pop             67.5
# Alanis Morissette – Ironic                              Pop             29.0
#
#                                                     Manhattan Distance  \
# No Doubt – Dont Speak.wav                                          2.0
# Modjo – Lady (Hear Me Tonight).wav                                 6.0
# Earth Wind and Fire – Sing a Song                                  9.0
# Led Zeppelin – Night Flight                                        5.0
# Dexter Gordon – Willow Weep For Me                                 7.0
# Nirvana – Come As You Are.wav                                     12.0
# David Christie – Saddle Up                                         8.0
# Gregory Isaacs – John Law                                          3.0
# Ini Kamoze – Here Comes The Hot Stepper(remix)                    46.0
# Dennis Brown – It's Magic                                         20.0
# Maroon 5 – Sugar.wav                                              21.0
# Dexter Gordon – Our Love Is Here To Stay                          11.0
# PIZZA – Романс.wav                                                42.0
# Ladysmith Black Mambazo – Leaning On The Everla...                14.0
# Alanis Morissette – Ironic                                        17.0
#
#                                                     Correlation Distance  \
# No Doubt – Dont Speak.wav                                           21.0
# Modjo – Lady (Hear Me Tonight).wav                                  34.0
# Earth Wind and Fire – Sing a Song                                    9.0
# Led Zeppelin – Night Flight                                         10.0
# Dexter Gordon – Willow Weep For Me                                  18.5
# Nirvana – Come As You Are.wav                                       51.5
# David Christie – Saddle Up                                          26.5
# Gregory Isaacs – John Law                                            3.0
# Ini Kamoze – Here Comes The Hot Stepper(remix)                      36.5
# Dennis Brown – It's Magic                                           71.5
# Maroon 5 – Sugar.wav                                                64.0
# Dexter Gordon – Our Love Is Here To Stay                            46.5
# PIZZA – Романс.wav                                                  64.0
# Ladysmith Black Mambazo – Leaning On The Everla...                  71.5
# Alanis Morissette – Ironic                                          28.5
#
#                                                     Canberra Distance  \
# No Doubt – Dont Speak.wav                                         5.0
# Modjo – Lady (Hear Me Tonight).wav                               15.0
# Earth Wind and Fire – Sing a Song                                16.0
# Led Zeppelin – Night Flight                                      88.0
# Dexter Gordon – Willow Weep For Me                               99.0
# Nirvana – Come As You Are.wav                                     2.0
# David Christie – Saddle Up                                      114.0
# Gregory Isaacs – John Law                                       174.0
# Ini Kamoze – Here Comes The Hot Stepper(remix)                   35.0
# Dennis Brown – It's Magic                                        23.0
# Maroon 5 – Sugar.wav                                              3.0
# Dexter Gordon – Our Love Is Here To Stay                        124.0
# PIZZA – Романс.wav                                               13.0
# Ladysmith Black Mambazo – Leaning On The Everla...               97.0
# Alanis Morissette – Ironic                                      102.0
#
#                                                     Chebyshev Distance  \
# No Doubt – Dont Speak.wav                                         11.0
# Modjo – Lady (Hear Me Tonight).wav                                 7.0
# Earth Wind and Fire – Sing a Song                                 44.0
# Led Zeppelin – Night Flight                                        3.0
# Dexter Gordon – Willow Weep For Me                                 6.0
# Nirvana – Come As You Are.wav                                     33.0
# David Christie – Saddle Up                                         4.0
# Gregory Isaacs – John Law                                          2.0
# Ini Kamoze – Here Comes The Hot Stepper(remix)                    13.0
# Dennis Brown – It's Magic                                         12.0
# Maroon 5 – Sugar.wav                                              31.0
# Dexter Gordon – Our Love Is Here To Stay                           8.0
# PIZZA – Романс.wav                                                30.0
# Ladysmith Black Mambazo – Leaning On The Everla...                 9.0
# Alanis Morissette – Ironic                                        64.0
#
#                                                     Euclidean Distance   Rank
# No Doubt – Dont Speak.wav                                          4.0   69.0
# Modjo – Lady (Hear Me Tonight).wav                                 7.0  104.0
# Earth Wind and Fire – Sing a Song                                 17.0  104.5
# Led Zeppelin – Night Flight                                        3.0  117.0
# Dexter Gordon – Willow Weep For Me                                 6.0  153.5
# Nirvana – Come As You Are.wav                                     13.0  160.5
# David Christie – Saddle Up                                         5.0  181.5
# Gregory Isaacs – John Law                                          2.0  187.0
# Ini Kamoze – Here Comes The Hot Stepper(remix)                    29.0  192.0
# Dennis Brown – It's Magic                                         18.0  208.5
# Maroon 5 – Sugar.wav                                              36.0  215.0
# Dexter Gordon – Our Love Is Here To Stay                          10.0  248.5
# PIZZA – Романс.wav                                                43.0  252.0
# Ladysmith Black Mambazo – Leaning On The Everla...                11.0  270.0
# Alanis Morissette – Ironic                                        30.0  270.5

# %%
listen_audio('Ani DiFranco – Shy')
# Out:
# Ani DiFranco – Shy
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
